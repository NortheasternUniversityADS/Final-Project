# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Importing libraries.

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
import datetime
import calendar
import numpy as np 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
from matplotlib.pylab import rcParams
import seaborn as sns

# %% [markdown]
# Importing `csv` file.

# %%
df = pd.read_csv('ckd.csv')

# %% [markdown]
# Finding co-relation between columns.

# %%
corr_df = df.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr_df, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_df, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.title('Correlations between different predictors')
plt.show()

# %% [markdown]
# We can see from the heat map that 'hemo' , 'pcv' are columns with lowest numerical value and 'bu' have highest numerical value in columns in our datset.

# %%
df1 = pd.read_csv('kidney_disease.csv')

# %% [markdown]
# We have lots of data in our dataset which have boolean values. Let's plot graph for every other column showing their count.

# %% [markdown]
# **Red Blood Cell**

# %%
rbc = pd.DataFrame(df1.groupby('rbc').size()).idxmax()[0]
df1['rbc'] = df1['rbc'].fillna(rbc)

sns.countplot(data=df1,x='rbc')

# %% [markdown]
# There are more entries with normal red blood cell in our dataset.

# %% [markdown]
# **Packed Cell**

# %%
pc = pd.DataFrame(df1.groupby('pc').size()).idxmax()[0]
df1['pc'] = df1['pc'].fillna(pc)

sns.countplot(data=df1,x='pc')

# %% [markdown]
# There are more entries with normal packed cell in our dataset.

# %% [markdown]
# **Prothombin Complex Concentrate**

# %%
pcc = pd.DataFrame(df1.groupby('pcc').size()).idxmax()[0]
df1['pcc'] = df1['pcc'].fillna(pcc)
sns.countplot(data=df1,x='pcc')

# %% [markdown]
# There are more entries with no PCC in our dataset.

# %% [markdown]
# **Barium**

# %%
ba = pd.DataFrame(df1.groupby('ba').size()).idxmax()[0]
df1['ba'] = df1['ba'].fillna(pcc)
sns.countplot(data=df1,x='ba')

# %% [markdown]
# There are more entries with no Barium in our dataset.

# %% [markdown]
# **Hypertension**

# %%
htn = pd.DataFrame(df1.groupby('htn').size()).idxmax()[0]
df1['htn'] = df1['htn'].fillna(htn)
sns.countplot(data=df1,x='htn')

# %% [markdown]
# There are more entries with 'no' in our dataset.

# %% [markdown]
# **Diabetes Mellitus**

# %%
dm = pd.DataFrame(df1.groupby('dm').size()).idxmax()[0]
df1['dm'] = df1['dm'].fillna(dm)
sns.countplot(data=df1,x='dm')

# %% [markdown]
# There are more entries with 'no' in our dataset.

# %% [markdown]
# **Coronary Artery Disease**

# %%
cad = pd.DataFrame(df1.groupby('cad').size()).idxmax()[0]
df1['cad'] = df1['cad'].fillna(cad)
sns.countplot(data=df1,x='cad')

# %% [markdown]
# There are more entries with 'no' in our dataset.

# %% [markdown]
# **Appetite**

# %%
appet = pd.DataFrame(df1.groupby('appet').size()).idxmax()[0]
df1['appet'] = df1['appet'].fillna(appet)
sns.countplot(data=df1,x='appet')

# %% [markdown]
# There are more entries with 'good' appetite in our dataset.

# %% [markdown]
# **Pulmonary Embolism**

# %%
pe = pd.DataFrame(df1.groupby('pe').size()).idxmax()[0]
df1['pe'] = df1['pe'].fillna(pe)
sns.countplot(data=df1,x='pe')

# %% [markdown]
# There are more entries with 'no' in our dataset.

# %% [markdown]
# **Audible Nasal Emission**

# %%
ane = pd.DataFrame(df1.groupby('ane').size()).idxmax()[0]
df1['ane'] = df1['ane'].fillna(ane)
sns.countplot(data=df1,x='ane')

# %% [markdown]
# There are more entries with 'no' in our dataset.

# %% [markdown]
# **Disease detected or not**

# %%
classi = pd.DataFrame(df1.groupby('classification').size()).idxmax()[0]
df1['classification'] = df1['classification'].fillna(classi)
sns.countplot(data=df1,x='classification')

# %% [markdown]
# There are more entries with diseases in our dataset.

# %% [markdown]
# EDA is also continued in Tableau. Link for them are mentioned below.

# %% [markdown]
# https://public.tableau.com/profile/nitin.prince.reuben#!/vizhome/EDA_1_2/Story1?publish=yes

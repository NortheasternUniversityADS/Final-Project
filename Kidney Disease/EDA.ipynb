# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Importing libraries.

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
import datetime
import calendar
import numpy as np 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
from matplotlib.pylab import rcParams
import seaborn as sns

# %% [markdown]
# Importing `csv` file.

# %%
df = pd.read_csv('ckd.csv')

# %% [markdown]
# Finding co-relation between columns.

# %%
corr_df = df.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr_df, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_df, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.title('Correlations between different predictors')
plt.show()

# %% [markdown]
# We can see from the heat map that 'hemo' , 'pcv' are columns with lowest numerical value and 'bu' have highest numerical value in columns in our datset.

# %%
df1 = pd.read_csv('kidney_disease.csv')

# %% [markdown]
# We have lots of data in our dataset which have boolean values. Let's plot graph for every other column showing their count.

# %%
df1.shape
# Out:
# (400, 26)

# %%
df1.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %% [markdown]
# **Red Blood Cell**

# %%
d = df1.groupby(['rbc', 'classification']).size().unstack(level=1)
d = d / d.count()
p = d.plot(kind='bar')

# %% [markdown]
# Patients with normal red blood cell count does not suffer from kidney disease.

# %% [markdown]
# **Packed Cell**

# %%
d = df1.groupby(['pc', 'classification']).size().unstack(level=1)
d = d / d.count()
p = d.plot(kind='bar')

# %% [markdown]
# Patients with normal packed cell count does not suffer from kidney disease.

# %% [markdown]
# **Prothombin Complex Concentrate**

# %%
d = df1.groupby(['pcc', 'classification']).size().unstack(level=1)
d = d / d.count()
p = d.plot(kind='bar')

# %% [markdown]
# Patients who lack Prothombin Complex Concemtreate are likely to suffer kidney disease.

# %% [markdown]
# **Barium**

# %%
d = df1.groupby(['ba', 'classification']).size().unstack(level=1)
d = d / d.count()
p = d.plot(kind='bar')

# %% [markdown]
# Patients who lack Barium are likely to suffer kidney disease.

# %% [markdown]
# **Hypertension**

# %%
d = df1.groupby(['htn', 'classification']).size().unstack(level=1)
d = d / d.count()
p = d.plot(kind='bar')

# %% [markdown]
# Patients who lack hypertension are likely to suffer kidney disease.

# %% [markdown]
# **Diabetes Mellitus**

# %%
d = df1.groupby(['dm', 'classification']).size().unstack(level=1)
d = d / d.count()
p = d.plot(kind='bar')

# %% [markdown]
# Patients who lack diabetes mellitus are likely to suffer kidney disease.

# %% [markdown]
# **Coronary Artery Disease**

# %%
d = df1.groupby(['cad', 'classification']).size().unstack(level=1)
d = d / d.count()
p = d.plot(kind='bar')

# %% [markdown]
# Patients who lack coronary artery disease are likely to suffer kidney disease.

# %% [markdown]
# **Appetite**

# %%
d = df1.groupby(['appet', 'classification']).size().unstack(level=1)
d = d / d.count()
p = d.plot(kind='bar')

# %% [markdown]
# Patients who have good appetite are likely to suffer kidney disease.

# %% [markdown]
# **Pulmonary Embolism**

# %%
d = df1.groupby(['pe', 'classification']).size().unstack(level=1)
d = d / d.count()
p = d.plot(kind='bar')

# %% [markdown]
# Patients who lack Pulmonary Embolism are likely to suffer kidney disease.

# %% [markdown]
# **Audible Nasal Emission**

# %%
d = df1.groupby(['ane', 'classification']).size().unstack(level=1)
d = d / d.count()
p = d.plot(kind='bar')

# %% [markdown]
# Patients who lack Audible Nasal Emission are likely to suffer kidney disease.

# %% [markdown]
# **Disease detected or not**

# %%
classi = pd.DataFrame(df1.groupby('classification').size()).idxmax()[0]
df1['classification'] = df1['classification'].fillna(classi)
sns.countplot(data=df1,x='classification')

# %% [markdown]
# There are more entries with diseases in our dataset.

# %% [markdown]
# EDA is also continued in Tableau. Link for them are mentioned below.

# %% [markdown]
# https://public.tableau.com/profile/nitin.prince.reuben#!/vizhome/EDA_1_2/Story1?publish=yes
